# %% [markdown]
# <a href="https://colab.research.google.com/github/SARO2326/FundamentosProgramacion/blob/main/Unidad1/Programa_2_Sistemas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
variable1=70
variable2=70
if variable1 < variable2:
   print(variable1,"es mayor que", variable2)
elif variable1 == variable2:
   print(variable1,"es igual que", variable2)
else:
   print(variable2, "es menor que", variable2)

variable1=10
variable2=70
if variable1 < variable2:
   print(variable1,"es mayor que", variable2)
elif variable1 == variable2:
   print(variable1,"es igual que", variable2)
else:
   print(variable2, "es menor que", variable2)

variable1=80
variable2=50
if variable1 < variable2:
   print(variable1,"es mayor que", variable2)
elif variable1 == variable2:
   print(variable1,"es igual que", variable2)
else:
   print(variable2, "es menor que", variable2)


variable1=90
variable2=30
if variable1 < variable2:
   print(variable1,"es mayor que", variable2)
elif variable1 == variable2:
   print(variable1,"es igual que", variable2)
else:
   print(variable2, "es menor que", variable2)
# Out:
# 70 es igual que 70
# 10 es mayor que 70
# 50 es menor que 50
# 30 es menor que 30

# %%
edad=int(input("Dame tu edad"))
if edad <= 10:
  print("Eres un niño")
elif edad <= 18:
  print("Eres un adolescente")
elif edad <= 30:
  print("Eres un joven adulto")
elif edad <= 59:
  print("Eres un adulto mayor")
# Out:
# Dame tu edad0
# Eres un niño

# %%
edad=int(input("Dame tu edad"))
if edad >= 65:
  print("Eres un adulto")
elif edad >= 30:
  print("Eres un joven adulto")
elif edad >= 18:
  print("Eres un adolescente")
elif edad >= 10:
  print("Eres un niño")
# Out:
# Dame tu edad20
# Eres un adolescente

# %%
5
