# %% [markdown]
# <a href="https://colab.research.google.com/github/SARO2326/FundamentosProgramacion/blob/main/Unidad1/Programa_1_Sistemas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
base = int (input("Dame la base del triangulo "))
altura = int (input("Dame la altura del triangulo "))
area = (base*altura)/2
print ("El area del triangulo es", area)
# Out:
# Dame la base del triangulo 2
# Dame la altura del triangulo 2
# El area del triangulo es 2.0

# %%
variable1 = 30
variable2 = 50
if variable1 > variable2:
  print("La variable1 es mayor es mayr que la variable2")
else:
  print ("La variable2 es mayor que la variable1")
# Out:
# La variable2 es mayor que la variable1

# %%
variable1 = 30
variable2 = 50
if variable1 > variable2:
  print(variable1,"es mayor que",variable2)
else:
  print(variable2,"es mayor que",variable1)
# Out:
# 50 es mayor que 30
